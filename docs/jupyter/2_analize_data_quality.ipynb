# %% [markdown]
# ----
# # Raspberry Pi
# ----

# %% [markdown]
# **Analyze fastq.gz files using fastqc command:**
#
# This will produce a .html report file containing analysis results and a .zip file which contains the analysis images and results

# %%
# %%bash
#
# # Test code only, use the next code for actual runs:
# # fastqc /var/www/html/usb/jupyter/my_projects/data/SRP093363/fastq/SRR5017135.fastq.gz
# Out:
# application/gzip
# Started analysis of SRR5017135.fastq.gz

# %%
# %%bash
#
# FASTQ_DIR="/var/www/html/usb/jupyter/my_projects/data/SRP093363/fastq"
#
# # Change the dir name to:
# # FASTQ_DIR="/var/www/html/usb/jupyter/my_projects/data/SRP093363/fastq_gz"
#
# FASTQC_DIR="/var/www/html/usb/jupyter/my_projects/data/SRP093363/fastqc-untrimmed-results"
#
# # Create FastQC output folder
# mkdir -p "$FASTQC_DIR"
#
# find "$FASTQ_DIR" -name "*.fastq.gz" | while read FILE; do
#
#     BASENAME=$(basename "$FILE")
#
#     echo "Running FastQC on $BASENAME"
#
#     fastqc \
#         "$FILE" \
#         --outdir "$FASTQC_DIR"
#
# done
# Out:
# Running FastQC on SRR5017138.fastq.gz
# application/gzip
# Started analysis of SRR5017138.fastq.gz
# Approx 5% complete for SRR5017138.fastq.gz
# Approx 10% complete for SRR5017138.fastq.gz
# Approx 15% complete for SRR5017138.fastq.gz
# Approx 20% complete for SRR5017138.fastq.gz
# Approx 25% complete for SRR5017138.fastq.gz
# Approx 30% complete for SRR5017138.fastq.gz
# Approx 35% complete for SRR5017138.fastq.gz
# Approx 40% complete for SRR5017138.fastq.gz
# Approx 45% complete for SRR5017138.fastq.gz
# Approx 50% complete for SRR5017138.fastq.gz
# Approx 55% complete for SRR5017138.fastq.gz
# Approx 60% complete for SRR5017138.fastq.gz
# Approx 65% complete for SRR5017138.fastq.gz
# Approx 70% complete for SRR5017138.fastq.gz
# Approx 75% complete for SRR5017138.fastq.gz
# Approx 80% complete for SRR5017138.fastq.gz
# Approx 85% complete for SRR5017138.fastq.gz
# Approx 90% complete for SRR5017138.fastq.gz
# Approx 95% complete for SRR5017138.fastq.gz
# ...

# %% [markdown]
# **Move the output of the fastqc analysis to the fastqc-untrimmmed-results folder:**

# %%
# %%bash

# FASTQC_UNTRIM="/var/www/html/usb/jupyter/my_projects/data/SRP093363/fastqc-untrimmed-results"

# # Create FastQC output folder
# mkdir -p "$FASTQC_UNTRIM"

# mv /var/www/html/usb/jupyter/my_projects/data/SRP093363/fastqc/*.zip /var/www/html/usb/jupyter/my_projects/data/SRP093363/fastqc-untrimmed-results
# mv /var/www/html/usb/jupyter/my_projects/data/SRP093363/fastqc/*.html /var/www/html/usb/jupyter/my_projects/data/SRP093363/fastqc-untrimmed-results
